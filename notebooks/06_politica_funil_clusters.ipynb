# %%
import pandas as pd
from pathlib import Path

root = Path("..")
tables = root / "reports" / "tables"
ano = 2025

geral = pd.read_csv(tables / f"politica_funil_{ano}_out_nov_dez_geral_mes.csv")
pol_mes = pd.read_csv(tables / f"politica_funil_{ano}_out_nov_dez_politica_mes.csv")
pol_periodo = pd.read_csv(tables / f"politica_funil_{ano}_out_nov_dez_politica_periodo.csv")
clusters = pd.read_csv(tables / f"clusters_{ano}_out_nov_dez_kpis.csv")
mix = pd.read_csv(tables / f"clusters_{ano}_out_nov_dez_mix_politica.csv")

geral, pol_periodo.head(15), clusters.head(10)
# Out:
# (       mes  n_propostas  valor_emprestado_total  valor_emprestado_medio  \
#  0  2025-10        285.0              916942.882             3217.343446
#  1  2025-11        207.0              674255.012             3257.270589
#  2  2025-12         66.0              255517.725             3871.480682
#
#     taxa_media  score_medio  incident_rate_pct  rebate_share_pct  \
#  0         NaN   812.471831          36.842105               0.0
#  1         NaN   807.922705          20.772947               0.0
#  2         NaN   802.878788           1.515152               0.0
#
#     rebate_spread_medio  paid_p1_rate_pct
#  0                  NaN         92.631579
#  1                  NaN         73.913043
#  2                  NaN          6.060606  ,
#     Política  n_propostas  valor_emprestado_total  valor_emprestado_medio  \
#  0       NaN        558.0             1846715.619             3309.526199
#
#     taxa_media  score_medio  incident_rate_pct  rebate_share_pct  \
# ...
