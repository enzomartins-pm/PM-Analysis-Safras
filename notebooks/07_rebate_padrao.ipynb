# %%
import pandas as pd
from pathlib import Path

root = Path("..")
tables = root / "reports" / "tables"
ano = 2025

mes = pd.read_csv(tables / f"rebate_{ano}_out_nov_dez_mes.csv")
pol = pd.read_csv(tables / f"rebate_{ano}_out_nov_dez_por_Política.csv")
clin = pd.read_csv(tables / f"rebate_{ano}_out_nov_dez_por_Clinica.csv")
eff = pd.read_csv(tables / f"rebate_{ano}_out_nov_dez_effect_by_Política_score_bucket.csv")

mes, pol.head(15), clin.head(15), eff.head(20)
# Out:
# (       mes  n_propostas  valor_emprestado_total  rebate_share_pct  \
#  0  2025-10        285.0              916942.882               0.0
#  1  2025-11        207.0              674255.012               0.0
#  2  2025-12         66.0              255517.725               0.0
#
#     rebate_spread_medio  taxa_media  taxa_rebate_media  paid_p1_rate_pct  \
#  0                  NaN         NaN                NaN         92.631579
#  1                  NaN         NaN                NaN         73.913043
#  2                  NaN         NaN                NaN          6.060606
#
#     incident_rate_pct
#  0          36.842105
#  1          20.772947
#  2           1.515152  ,
#     Política  n_propostas  valor_emprestado_total  rebate_share_pct  \
#  0       NaN        558.0             1846715.619               0.0
#
#     rebate_spread_medio  taxa_media  taxa_rebate_media  paid_p1_rate_pct  \
#  0                  NaN         NaN                NaN         75.448029
#
# ...
