# %%
import pandas as pd
from pathlib import Path

root = Path("..")
tables = root / "reports" / "tables"
ano = 2025  # ajuste se necessário

geral = pd.read_csv(tables / f"emprego_kpis_{ano}_out_nov_dez_geral.csv")
macro = pd.read_csv(tables / f"emprego_kpis_{ano}_out_nov_dez_por_macro.csv")
macro_mes = pd.read_csv(tables / f"emprego_kpis_{ano}_out_nov_dez_por_macro_mes.csv")
prio = pd.read_csv(tables / f"emprego_prioridade_{ano}_out_nov_dez.csv")

geral, macro.head(15), prio.head(10)
# Out:
# (       mes  n_propostas  valor_emprestado_total  valor_emprestado_medio  \
#  0  2025-10        285.0              916942.882             3217.343446
#  1  2025-11        207.0              674255.012             3257.270589
#  2  2025-12         66.0              255517.725             3871.480682
#
#     taxa_media  score_medio  incident_rate_pct  rebate_share_pct  \
#  0         NaN   812.471831          36.842105               0.0
#  1         NaN   807.922705          20.772947               0.0
#  2         NaN   802.878788           1.515152               0.0
#
#     ph3a_empregado_share_pct
#  0                 37.543860
#  1                 34.782609
#  2                 37.878788  ,
#    employment_macro  n_propostas  valor_emprestado_total  \
#  0     AUTONOMO/MEI        340.0              987771.110
#  1              NaN        172.0              643695.610
#  2              CLT         23.0              114958.899
# ...
